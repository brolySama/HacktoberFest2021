# %%
import bs4
from bs4 import BeautifulSoup
import requests

# %%
html_text=requests.get('https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=0001605941&type=485%25&dateb=&owner=include&start=0&count=40').text
print(html_text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="ENG">
# <head>
# <title>EDGAR Search Results</title>
# <link href="/include/interactive.css" rel="stylesheet" type="text/css" />
# <link href="/edgar/search/css/smartSearchCompanyLanding.css" rel="stylesheet" type="text/css" />
# <script language="JavaScript" src="/edgar/search/js/smartSearchCompanyLanding.js" type="text/javascript"></script>
# <link rel="alternate" type="application/atom+xml" title="ATOM" href="/cgi-bin/browse-edgar?action=getcompany&amp;CIK=0001605941&amp;type=485%25&amp;dateb=&amp;owner=include&amp;count=40&amp;output=atom" />
#
# </head>
# <body style="margin: 0">
# <!-- SEC Web Analytics - For information please visit: https://www.sec.gov/privacy.htm#collectedinfo -->
# <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-TD3BKV"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# ...

# %%
soup = BeautifulSoup(html_text, 'lxml')

# %%
doc=soup.find_all("td",scope="row")
doc_name=(doc[2].find("a").text)
doc_name
# Out:
# 'd44626d485bpos.htm'

# %%
# Out:
# <a href="/cgi-bin/browse-edgar?action=getcompany&amp;CIK=C000165757">C000165757</a>

# %%
ing=""
for i in s:
    ing+=i
ing
# Out:
# '1485BPOSd44626d485bpos.htm \xa0\xa0iXBRL485BPOS130440152AMENDED AND RESTATED ADVISORY AGREEMENT DTD JULY 16, 2020d44626dex99d1.htmEX-99.(D)(1)706963AMENDMENT NO.1 TO ADVISORY AGREEMENT DTD JULY 31, 2020 BTWN 1290 FUNDS AND EIMd44626dex99d1i.htmEX-99.(D)(1)(I)276504SUB-ADVISORY AGREEMENT BTWN EIM AND AXA IM DTD JULY 31. 2020d44626dex99d2.htmEX-99.(D)(2)853365SUB-ADVISORY AGREEMENT BTWN EIM AND AXA ROSENBERG DTD JULY 16, 2020d44626dex99d3.htmEX-99.(D)(3)916086GAMCO SUB-ADVISORY AGREEMENT BTWN EIM AND GAMCOd44626dex99d4.htmEX-99.(D)(4)922017SUB-ADVISORY AGREEMENT BTWN EIM AND DOUBLELINE DTD JULY 16, 2020d44626dex99d5.htmEX-99.(D)(5)978878SUB-ADVISORY AGREEMENT BTWN EIM AND BRANDYWINE DTD JULY 16, 2020d44626dex99d6.htmEX-99.(D)(6)967389AMENDMENT NO. 2 DTD DECEMBER 14, 2020 TO THE DISTRIBUTION AGREEMENTd44626dex99e1ii.htmEX-99.(E)(1)(II)1295410AMENDMENT NO. 8 BTWN 1290 FUNDS AND JPMORGAN DTD JULY 31, 2020d44626dex99g1viii.htmEX-99.(G)(1)(VIII)881411MUTUAL FUNDS SERVICE AGREEMENT BTWN 129
# ...

# %%
td=soup.find_all("td")
no=td[8].text.split("-")
no=no[1].split("\xa0")
no=no[0].replace(" ","")
no=int(no)

# %%
no%40
# Out:
# 0
